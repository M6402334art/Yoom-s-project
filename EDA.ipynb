# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
g1 = pd.read_csv('files/Good1.csv')
g2 = pd.read_csv('files/Good2.csv')
g3 = pd.read_csv('files/Good3.csv')
g4 = pd.read_csv('files/Good4.csv')
g5 = pd.read_csv('files/Good5.csv')
g6 = pd.read_csv('files/Good6.csv')
g7 = pd.read_csv('files/Good7.csv')
g8 = pd.read_csv('files/Good8.csv')
g9 = pd.read_csv('files/Good9.csv')
g10 = pd.read_csv('files/Good10.csv')
g11 = pd.read_csv('files/Good11.csv')
g12 = pd.read_csv('files/Good12.csv')
g13 = pd.read_csv('files/Good13.csv')
g14 = pd.read_csv('files/Good14.csv')
g15 = pd.read_csv('files/Good15.csv')
g16 = pd.read_csv('files/Good16.csv')
g17 = pd.read_csv('files/Good17.csv')
g18 = pd.read_csv('files/Good18.csv')
g19 = pd.read_csv('files/Good19.csv')
g20 = pd.read_csv('files/Good20.csv')
g21 = pd.read_csv('files/Good21.csv')
g22 = pd.read_csv('files/Good22.csv')
g23 = pd.read_csv('files/Good23.csv')
g24 = pd.read_csv('files/Good24.csv')
g25 = pd.read_csv('files/Good25.csv')
g26 = pd.read_csv('files/Good26.csv')
g27 = pd.read_csv('files/Good27.csv')
g28 = pd.read_csv('files/Good28.csv')
g29 = pd.read_csv('files/Good29.csv')
g30 = pd.read_csv('files/Good30.csv')
b1 = pd.read_csv('files/Bad1.csv')
b2 = pd.read_csv('files/Bad2.csv')
b3 = pd.read_csv('files/Bad3.csv')
b4 = pd.read_csv('files/Bad4.csv')
b5 = pd.read_csv('files/Bad5.csv')
b6 = pd.read_csv('files/Bad6.csv')
b7 = pd.read_csv('files/Bad7.csv')
b8 = pd.read_csv('files/Bad8.csv')
b9 = pd.read_csv('files/Bad9.csv')
b10 = pd.read_csv('files/Bad10.csv')
b11 = pd.read_csv('files/Bad11.csv')
b12 = pd.read_csv('files/Bad12.csv')
b13 = pd.read_csv('files/Bad13.csv')
b14 = pd.read_csv('files/Bad14.csv')
b15 = pd.read_csv('files/Bad15.csv')
b16 = pd.read_csv('files/Bad16.csv')
b17 = pd.read_csv('files/Bad17.csv')
b18 = pd.read_csv('files/Bad18.csv')
b19 = pd.read_csv('files/Bad19.csv')
b20 = pd.read_csv('files/Bad20.csv')

# %%
# Good Data, Line plot Heat, Cool, Temp

fig, axs = plt.subplots(6,5, figsize=(30,25))

# 1
ax1_1 = axs[0,0]
ax1_1.set_xlabel('time')
ax1_1.set_ylabel('PWM')
ax1_1.plot(g1['HeatDmd'].index, g1['HeatDmd'], '-', color='blue', label='heat')
ax1_1.plot(g1['CoolDmd'].index, g1['CoolDmd'], '-', color='orange', label='cool')
ax1_1.legend()
ax1_2 = ax1_1.twinx()
ax1_2.set_ylabel('temp')
ax1_2.plot(g1['FlowTemp_Tenths'].index, g1['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax1_2.legend()

# 2
ax2_1 = axs[0,1]
ax2_1.set_xlabel('time')
ax2_1.set_ylabel('PWM')
ax2_1.plot(g2['HeatDmd'].index, g2['HeatDmd'], '-', color='blue', label='heat')
ax2_1.plot(g2['CoolDmd'].index, g2['CoolDmd'], '-', color='orange', label='cool')
ax2_1.legend()
ax2_2 = ax2_1.twinx()
ax2_2.set_ylabel('temp')
ax2_2.plot(g2['FlowTemp_Tenths'].index, g2['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax2_2.legend()

# 3
ax3_1 = axs[0,2]
ax3_1.set_xlabel('time')
ax3_1.set_ylabel('PWM')
ax3_1.plot(g3['HeatDmd'].index, g3['HeatDmd'], '-', color='blue', label='heat')
ax3_1.plot(g3['CoolDmd'].index, g3['CoolDmd'], '-', color='orange', label='cool')
ax3_1.legend()
ax3_2 = ax3_1.twinx()
ax3_2.set_ylabel('temp')
ax3_2.plot(g3['FlowTemp_Tenths'].index, g3['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax3_2.legend()

# 4
ax4_1 = axs[0,3]
ax4_1.set_xlabel('time')
ax4_1.set_ylabel('PWM')
ax4_1.plot(g4['HeatDmd'].index, g4['HeatDmd'], '-', color='blue', label='heat')
ax4_1.plot(g4['CoolDmd'].index, g4['CoolDmd'], '-', color='orange', label='cool')
ax4_1.legend()
ax4_2 = ax4_1.twinx()
ax4_2.set_ylabel('temp')
ax4_2.plot(g4['FlowTemp_Tenths'].index, g4['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax4_2.legend()

# 5
ax5_1 = axs[0,4]
ax5_1.set_xlabel('time')
ax5_1.set_ylabel('PWM')
ax5_1.plot(g5['HeatDmd'].index, g5['HeatDmd'], '-', color='blue', label='heat')
ax5_1.plot(g5['CoolDmd'].index, g5['CoolDmd'], '-', color='orange', label='cool')
ax5_1.legend()
ax5_2 = ax5_1.twinx()
ax5_2.set_ylabel('temp')
ax5_2.plot(g5['FlowTemp_Tenths'].index, g5['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax5_2.legend()

# 6
ax6_1 = axs[1,0]
ax6_1.set_xlabel('time')
ax6_1.set_ylabel('PWM')
ax6_1.plot(g6['HeatDmd'].index, g6['HeatDmd'], '-', color='blue', label='heat')
ax6_1.plot(g6['CoolDmd'].index, g6['CoolDmd'], '-', color='orange', label='cool')
ax6_1.legend()
ax6_2 = ax6_1.twinx()
ax6_2.set_ylabel('temp')
ax6_2.plot(g6['FlowTemp_Tenths'].index, g6['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax6_2.legend()

# 7
ax7_1 = axs[1,1]
ax7_1.set_xlabel('time')
ax7_1.set_ylabel('PWM')
ax7_1.plot(g7['HeatDmd'].index, g7['HeatDmd'], '-', color='blue', label='heat')
ax7_1.plot(g7['CoolDmd'].index, g7['CoolDmd'], '-', color='orange', label='cool')
ax7_1.legend()
ax7_2 = ax7_1.twinx()
ax7_2.set_ylabel('temp')
ax7_2.plot(g7['FlowTemp_Tenths'].index, g7['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax7_2.legend()

# 8
ax8_1 = axs[1,2]
ax8_1.set_xlabel('time')
ax8_1.set_ylabel('PWM')
ax8_1.plot(g8['HeatDmd'].index, g8['HeatDmd'], '-', color='blue', label='heat')
ax8_1.plot(g8['CoolDmd'].index, g8['CoolDmd'], '-', color='orange', label='cool')
ax8_1.legend()
ax8_2 = ax8_1.twinx()
ax8_2.set_ylabel('temp')
ax8_2.plot(g8['FlowTemp_Tenths'].index, g8['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax8_2.legend()

# 9
ax9_1 = axs[1,3]
ax9_1.set_xlabel('time')
ax9_1.set_ylabel('PWM')
ax9_1.plot(g9['HeatDmd'].index, g9['HeatDmd'], '-', color='blue', label='heat')
ax9_1.plot(g9['CoolDmd'].index, g9['CoolDmd'], '-', color='orange', label='cool')
ax9_1.legend()
ax9_2 = ax9_1.twinx()
ax9_2.set_ylabel('temp')
ax9_2.plot(g9['FlowTemp_Tenths'].index, g9['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax9_2.legend()

# 10
ax10_1 = axs[1,4]
ax10_1.set_xlabel('time')
ax10_1.set_ylabel('PWM')
ax10_1.plot(g10['HeatDmd'].index, g10['HeatDmd'], '-', color='blue', label='heat')
ax10_1.plot(g10['CoolDmd'].index, g10['CoolDmd'], '-', color='orange', label='cool')
ax10_1.legend()
ax10_2 = ax10_1.twinx()
ax10_2.set_ylabel('temp')
ax10_2.plot(g10['FlowTemp_Tenths'].index, g10['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax10_2.legend()

# 11
ax11_1 = axs[2,0]
ax11_1.set_xlabel('time')
ax11_1.set_ylabel('PWM')
ax11_1.plot(g11['HeatDmd'].index, g11['HeatDmd'], '-', color='blue', label='heat')
ax11_1.plot(g11['CoolDmd'].index, g11['CoolDmd'], '-', color='orange', label='cool')
ax11_1.legend()
ax11_2 = ax11_1.twinx()
ax11_2.set_ylabel('temp')
ax11_2.plot(g11['FlowTemp_Tenths'].index, g11['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax11_2.legend()

# 12
ax12_1 = axs[2,1]
ax12_1.set_xlabel('time')
ax12_1.set_ylabel('PWM')
ax12_1.plot(g12['HeatDmd'].index, g12['HeatDmd'], '-', color='blue', label='heat')
ax12_1.plot(g12['CoolDmd'].index, g12['CoolDmd'], '-', color='orange', label='cool')
ax12_1.legend()
ax12_2 = ax12_1.twinx()
ax12_2.set_ylabel('temp')
ax12_2.plot(g12['FlowTemp_Tenths'].index, g12['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax12_2.legend()

# 13
ax13_1 = axs[2,2]
ax13_1.set_xlabel('time')
ax13_1.set_ylabel('PWM')
ax13_1.plot(g13['HeatDmd'].index, g13['HeatDmd'], '-', color='blue', label='heat')
ax13_1.plot(g13['CoolDmd'].index, g13['CoolDmd'], '-', color='orange', label='cool')
ax13_1.legend()
ax13_2 = ax13_1.twinx()
ax13_2.set_ylabel('temp')
ax13_2.plot(g13['FlowTemp_Tenths'].index, g13['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax13_2.legend()

# 14
ax14_1 = axs[2,3]
ax14_1.set_xlabel('time')
ax14_1.set_ylabel('PWM')
ax14_1.plot(g14['HeatDmd'].index, g14['HeatDmd'], '-', color='blue', label='heat')
ax14_1.plot(g14['CoolDmd'].index, g14['CoolDmd'], '-', color='orange', label='cool')
ax14_1.legend()
ax14_2 = ax14_1.twinx()
ax14_2.set_ylabel('temp')
ax14_2.plot(g14['FlowTemp_Tenths'].index, g14['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax14_2.legend()

# 15
ax15_1 = axs[2,4]
ax15_1.set_xlabel('time')
ax15_1.set_ylabel('PWM')
ax15_1.plot(g15['HeatDmd'].index, g15['HeatDmd'], '-', color='blue', label='heat')
ax15_1.plot(g15['CoolDmd'].index, g15['CoolDmd'], '-', color='orange', label='cool')
ax15_1.legend()
ax15_2 = ax15_1.twinx()
ax15_2.set_ylabel('temp')
ax15_2.plot(g15['FlowTemp_Tenths'].index, g15['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax15_2.legend()

# 16
ax16_1 = axs[3,0]
ax16_1.set_xlabel('time')
ax16_1.set_ylabel('PWM')
ax16_1.plot(g16['HeatDmd'].index, g16['HeatDmd'], '-', color='blue', label='heat')
ax16_1.plot(g16['CoolDmd'].index, g16['CoolDmd'], '-', color='orange', label='cool')
ax16_1.legend()
ax16_2 = ax16_1.twinx()
ax16_2.set_ylabel('temp')
ax16_2.plot(g16['FlowTemp_Tenths'].index, g16['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax16_2.legend()

# 17
ax17_1 = axs[3,1]
ax17_1.set_xlabel('time')
ax17_1.set_ylabel('PWM')
ax17_1.plot(g17['HeatDmd'].index, g17['HeatDmd'], '-', color='blue', label='heat')
ax17_1.plot(g17['CoolDmd'].index, g17['CoolDmd'], '-', color='orange', label='cool')
ax17_1.legend()
ax17_2 = ax17_1.twinx()
ax17_2.set_ylabel('temp')
ax17_2.plot(g17['FlowTemp_Tenths'].index, g17['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax17_2.legend()

# 18
ax18_1 = axs[3,2]
ax18_1.set_xlabel('time')
ax18_1.set_ylabel('PWM')
ax18_1.plot(g18['HeatDmd'].index, g18['HeatDmd'], '-', color='blue', label='heat')
ax18_1.plot(g18['CoolDmd'].index, g18['CoolDmd'], '-', color='orange', label='cool')
ax18_1.legend()
ax18_2 = ax18_1.twinx()
ax18_2.set_ylabel('temp')
ax18_2.plot(g18['FlowTemp_Tenths'].index, g18['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax18_2.legend()

# 19
ax19_1 = axs[3,3]
ax19_1.set_xlabel('time')
ax19_1.set_ylabel('PWM')
ax19_1.plot(g19['HeatDmd'].index, g19['HeatDmd'], '-', color='blue', label='heat')
ax19_1.plot(g19['CoolDmd'].index, g19['CoolDmd'], '-', color='orange', label='cool')
ax19_1.legend()
ax19_2 = ax19_1.twinx()
ax19_2.set_ylabel('temp')
ax19_2.plot(g19['FlowTemp_Tenths'].index, g19['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax19_2.legend()

# 20
ax20_1 = axs[3,4]
ax20_1.set_xlabel('time')
ax20_1.set_ylabel('PWM')
ax20_1.plot(g20['HeatDmd'].index, g20['HeatDmd'], '-', color='blue', label='heat')
ax20_1.plot(g20['CoolDmd'].index, g20['CoolDmd'], '-', color='orange', label='cool')
ax20_1.legend()
ax20_2 = ax20_1.twinx()
ax20_2.set_ylabel('temp')
ax20_2.plot(g20['FlowTemp_Tenths'].index, g20['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax20_2.legend()

# 21
ax21_1 = axs[4,0]
ax21_1.set_xlabel('time')
ax21_1.set_ylabel('PWM')
ax21_1.plot(g21['HeatDmd'].index, g21['HeatDmd'], '-', color='blue', label='heat')
ax21_1.plot(g21['CoolDmd'].index, g21['CoolDmd'], '-', color='orange', label='cool')
ax21_1.legend()
ax21_2 = ax21_1.twinx()
ax21_2.set_ylabel('temp')
ax21_2.plot(g21['FlowTemp_Tenths'].index, g21['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax21_2.legend()

# 22
ax22_1 = axs[4,1]
ax22_1.set_xlabel('time')
ax22_1.set_ylabel('PWM')
ax22_1.plot(g22['HeatDmd'].index, g22['HeatDmd'], '-', color='blue', label='heat')
ax22_1.plot(g22['CoolDmd'].index, g22['CoolDmd'], '-', color='orange', label='cool')
ax22_1.legend()
ax22_2 = ax22_1.twinx()
ax22_2.set_ylabel('temp')
ax22_2.plot(g22['FlowTemp_Tenths'].index, g22['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax22_2.legend()

# 23
ax23_1 = axs[4,2]
ax23_1.set_xlabel('time')
ax23_1.set_ylabel('PWM')
ax23_1.plot(g23['HeatDmd'].index, g23['HeatDmd'], '-', color='blue', label='heat')
ax23_1.plot(g23['CoolDmd'].index, g23['CoolDmd'], '-', color='orange', label='cool')
ax23_1.legend()
ax23_2 = ax23_1.twinx()
ax23_2.set_ylabel('temp')
ax23_2.plot(g23['FlowTemp_Tenths'].index, g23['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax23_2.legend()

# 24
ax24_1 = axs[4,3]
ax24_1.set_xlabel('time')
ax24_1.set_ylabel('PWM')
ax24_1.plot(g24['HeatDmd'].index, g24['HeatDmd'], '-', color='blue', label='heat')
ax24_1.plot(g24['CoolDmd'].index, g24['CoolDmd'], '-', color='orange', label='cool')
ax24_1.legend()
ax24_2 = ax24_1.twinx()
ax24_2.set_ylabel('temp')
ax24_2.plot(g24['FlowTemp_Tenths'].index, g24['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax24_2.legend()

# 25
ax25_1 = axs[4,4]
ax25_1.set_xlabel('time')
ax25_1.set_ylabel('PWM')
ax25_1.plot(g25['HeatDmd'].index, g25['HeatDmd'], '-', color='blue', label='heat')
ax25_1.plot(g25['CoolDmd'].index, g25['CoolDmd'], '-', color='orange', label='cool')
ax25_1.legend()
ax25_2 = ax25_1.twinx()
ax25_2.set_ylabel('temp')
ax25_2.plot(g25['FlowTemp_Tenths'].index, g25['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax25_2.legend()

# 26
ax26_1 = axs[5,0]
ax26_1.set_xlabel('time')
ax26_1.set_ylabel('PWM')
ax26_1.plot(g26['HeatDmd'].index, g26['HeatDmd'], '-', color='blue', label='heat')
ax26_1.plot(g26['CoolDmd'].index, g26['CoolDmd'], '-', color='orange', label='cool')
ax26_1.legend()
ax26_2 = ax26_1.twinx()
ax26_2.set_ylabel('temp')
ax26_2.plot(g26['FlowTemp_Tenths'].index, g26['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax26_2.legend()

# 27
ax27_1 = axs[5,1]
ax27_1.set_xlabel('time')
ax27_1.set_ylabel('PWM')
ax27_1.plot(g27['HeatDmd'].index, g27['HeatDmd'], '-', color='blue', label='heat')
ax27_1.plot(g27['CoolDmd'].index, g27['CoolDmd'], '-', color='orange', label='cool')
ax27_1.legend()
ax27_2 = ax27_1.twinx()
ax27_2.set_ylabel('temp')
ax27_2.plot(g27['FlowTemp_Tenths'].index, g27['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax27_2.legend()

# 28
ax28_1 = axs[5,2]
ax28_1.set_xlabel('time')
ax28_1.set_ylabel('PWM')
ax28_1.plot(g28['HeatDmd'].index, g28['HeatDmd'], '-', color='blue', label='heat')
ax28_1.plot(g28['CoolDmd'].index, g28['CoolDmd'], '-', color='orange', label='cool')
ax28_1.legend()
ax28_2 = ax28_1.twinx()
ax28_2.set_ylabel('temp')
ax28_2.plot(g28['FlowTemp_Tenths'].index, g28['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax28_2.legend()

# 29
ax29_1 = axs[5,3]
ax29_1.set_xlabel('time')
ax29_1.set_ylabel('PWM')
ax29_1.plot(g29['HeatDmd'].index, g29['HeatDmd'], '-', color='blue', label='heat')
ax29_1.plot(g29['CoolDmd'].index, g29['CoolDmd'], '-', color='orange', label='cool')
ax29_1.legend()
ax29_2 = ax29_1.twinx()
ax29_2.set_ylabel('temp')
ax29_2.plot(g29['FlowTemp_Tenths'].index, g29['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax29_2.legend()

# 30
ax30_1 = axs[5,4]
ax30_1.set_xlabel('time')
ax30_1.set_ylabel('PWM')
ax30_1.plot(g30['HeatDmd'].index, g30['HeatDmd'], '-', color='blue', label='heat')
ax30_1.plot(g30['CoolDmd'].index, g30['CoolDmd'], '-', color='orange', label='cool')
ax30_1.legend()
ax30_2 = ax30_1.twinx()
ax30_2.set_ylabel('temp')
ax30_2.plot(g30['FlowTemp_Tenths'].index, g30['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax30_2.legend()

plt.show()

# %%
# Bad Data, Line plot Heat, Cool, Temp

fig, axs = plt.subplots(4,5, figsize=(30,25))

# 1
ax1_1 = axs[0,0]
ax1_1.set_xlabel('time')
ax1_1.set_ylabel('PWM')
ax1_1.plot(b1['HeatDmd'].index, b1['HeatDmd'], '-', color='blue', label='heat')
ax1_1.plot(b1['CoolDmd'].index, b1['CoolDmd'], '-', color='orange', label='cool')
ax1_1.legend()
ax1_2 = ax1_1.twinx()
ax1_2.set_ylabel('temp')
ax1_2.plot(b1['FlowTemp_Tenths'].index, b1['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax1_2.legend()

# 2
ax2_1 = axs[0,1]
ax2_1.set_xlabel('time')
ax2_1.set_ylabel('PWM')
ax2_1.plot(b2['HeatDmd'].index, b2['HeatDmd'], '-', color='blue', label='heat')
ax2_1.plot(b2['CoolDmd'].index, b2['CoolDmd'], '-', color='orange', label='cool')
ax2_1.legend()
ax2_2 = ax2_1.twinx()
ax2_2.set_ylabel('temp')
ax2_2.plot(b2['FlowTemp_Tenths'].index, b2['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax2_2.legend()

# 3
ax3_1 = axs[0,2]
ax3_1.set_xlabel('time')
ax3_1.set_ylabel('PWM')
ax3_1.plot(b3['HeatDmd'].index, b3['HeatDmd'], '-', color='blue', label='heat')
ax3_1.plot(b3['CoolDmd'].index, b3['CoolDmd'], '-', color='orange', label='cool')
ax3_1.legend()
ax3_2 = ax3_1.twinx()
ax3_2.set_ylabel('temp')
ax3_2.plot(b3['FlowTemp_Tenths'].index, b3['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax3_2.legend()

# 4
ax4_1 = axs[0,3]
ax4_1.set_xlabel('time')
ax4_1.set_ylabel('PWM')
ax4_1.plot(b4['HeatDmd'].index, b4['HeatDmd'], '-', color='blue', label='heat')
ax4_1.plot(b4['CoolDmd'].index, b4['CoolDmd'], '-', color='orange', label='cool')
ax4_1.legend()
ax4_2 = ax4_1.twinx()
ax4_2.set_ylabel('temp')
ax4_2.plot(b4['FlowTemp_Tenths'].index, b4['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax4_2.legend()

# 5
ax5_1 = axs[0,4]
ax5_1.set_xlabel('time')
ax5_1.set_ylabel('PWM')
ax5_1.plot(b5['HeatDmd'].index, b5['HeatDmd'], '-', color='blue', label='heat')
ax5_1.plot(b5['CoolDmd'].index, b5['CoolDmd'], '-', color='orange', label='cool')
ax5_1.legend()
ax5_2 = ax5_1.twinx()
ax5_2.set_ylabel('temp')
ax5_2.plot(b5['FlowTemp_Tenths'].index, b5['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax5_2.legend()

# 6
ax6_1 = axs[1,0]
ax6_1.set_xlabel('time')
ax6_1.set_ylabel('PWM')
ax6_1.plot(b6['HeatDmd'].index, b6['HeatDmd'], '-', color='blue', label='heat')
ax6_1.plot(b6['CoolDmd'].index, b6['CoolDmd'], '-', color='orange', label='cool')
ax6_1.legend()
ax6_2 = ax6_1.twinx()
ax6_2.set_ylabel('temp')
ax6_2.plot(b6['FlowTemp_Tenths'].index, b6['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax6_2.legend()

# 7
ax7_1 = axs[1,1]
ax7_1.set_xlabel('time')
ax7_1.set_ylabel('PWM')
ax7_1.plot(b7['HeatDmd'].index, b7['HeatDmd'], '-', color='blue', label='heat')
ax7_1.plot(b7['CoolDmd'].index, b7['CoolDmd'], '-', color='orange', label='cool')
ax7_1.legend()
ax7_2 = ax7_1.twinx()
ax7_2.set_ylabel('temp')
ax7_2.plot(b7['FlowTemp_Tenths'].index, b7['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax7_2.legend()

# 8
ax8_1 = axs[1,2]
ax8_1.set_xlabel('time')
ax8_1.set_ylabel('PWM')
ax8_1.plot(b8['HeatDmd'].index, b8['HeatDmd'], '-', color='blue', label='heat')
ax8_1.plot(b8['CoolDmd'].index, b8['CoolDmd'], '-', color='orange', label='cool')
ax8_1.legend()
ax8_2 = ax8_1.twinx()
ax8_2.set_ylabel('temp')
ax8_2.plot(b8['FlowTemp_Tenths'].index, b8['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax8_2.legend()

# 9
ax9_1 = axs[1,3]
ax9_1.set_xlabel('time')
ax9_1.set_ylabel('PWM')
ax9_1.plot(b9['HeatDmd'].index, b9['HeatDmd'], '-', color='blue', label='heat')
ax9_1.plot(b9['CoolDmd'].index, b9['CoolDmd'], '-', color='orange', label='cool')
ax9_1.legend()
ax9_2 = ax9_1.twinx()
ax9_2.set_ylabel('temp')
ax9_2.plot(b9['FlowTemp_Tenths'].index, b9['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax9_2.legend()

# 10
ax10_1 = axs[1,4]
ax10_1.set_xlabel('time')
ax10_1.set_ylabel('PWM')
ax10_1.plot(b10['HeatDmd'].index, b10['HeatDmd'], '-', color='blue', label='heat')
ax10_1.plot(b10['CoolDmd'].index, b10['CoolDmd'], '-', color='orange', label='cool')
ax10_1.legend()
ax10_2 = ax10_1.twinx()
ax10_2.set_ylabel('temp')
ax10_2.plot(b10['FlowTemp_Tenths'].index, b10['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax10_2.legend()

# 11
ax11_1 = axs[2,0]
ax11_1.set_xlabel('time')
ax11_1.set_ylabel('PWM')
ax11_1.plot(b11['HeatDmd'].index, b11['HeatDmd'], '-', color='blue', label='heat')
ax11_1.plot(b11['CoolDmd'].index, b11['CoolDmd'], '-', color='orange', label='cool')
ax11_1.legend()
ax11_2 = ax11_1.twinx()
ax11_2.set_ylabel('temp')
ax11_2.plot(b11['FlowTemp_Tenths'].index, b11['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax11_2.legend()

# 12
ax12_1 = axs[2,1]
ax12_1.set_xlabel('time')
ax12_1.set_ylabel('PWM')
ax12_1.plot(b12['HeatDmd'].index, b12['HeatDmd'], '-', color='blue', label='heat')
ax12_1.plot(b12['CoolDmd'].index, b12['CoolDmd'], '-', color='orange', label='cool')
ax12_1.legend()
ax12_2 = ax12_1.twinx()
ax12_2.set_ylabel('temp')
ax12_2.plot(b12['FlowTemp_Tenths'].index, b12['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax12_2.legend()

# 13
ax13_1 = axs[2,2]
ax13_1.set_xlabel('time')
ax13_1.set_ylabel('PWM')
ax13_1.plot(b13['HeatDmd'].index, b13['HeatDmd'], '-', color='blue', label='heat')
ax13_1.plot(b13['CoolDmd'].index, b13['CoolDmd'], '-', color='orange', label='cool')
ax13_1.legend()
ax13_2 = ax13_1.twinx()
ax13_2.set_ylabel('temp')
ax13_2.plot(b13['FlowTemp_Tenths'].index, b13['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax13_2.legend()

# 14
ax14_1 = axs[2,3]
ax14_1.set_xlabel('time')
ax14_1.set_ylabel('PWM')
ax14_1.plot(b14['HeatDmd'].index, b14['HeatDmd'], '-', color='blue', label='heat')
ax14_1.plot(b14['CoolDmd'].index, b14['CoolDmd'], '-', color='orange', label='cool')
ax14_1.legend()
ax14_2 = ax14_1.twinx()
ax14_2.set_ylabel('temp')
ax14_2.plot(b14['FlowTemp_Tenths'].index, b14['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax14_2.legend()

# 15
ax15_1 = axs[2,4]
ax15_1.set_xlabel('time')
ax15_1.set_ylabel('PWM')
ax15_1.plot(b15['HeatDmd'].index, b15['HeatDmd'], '-', color='blue', label='heat')
ax15_1.plot(b15['CoolDmd'].index, b15['CoolDmd'], '-', color='orange', label='cool')
ax15_1.legend()
ax15_2 = ax15_1.twinx()
ax15_2.set_ylabel('temp')
ax15_2.plot(b15['FlowTemp_Tenths'].index, b15['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax15_2.legend()

# 16
ax16_1 = axs[3,0]
ax16_1.set_xlabel('time')
ax16_1.set_ylabel('PWM')
ax16_1.plot(b16['HeatDmd'].index, b16['HeatDmd'], '-', color='blue', label='heat')
ax16_1.plot(b16['CoolDmd'].index, b16['CoolDmd'], '-', color='orange', label='cool')
ax16_1.legend()
ax16_2 = ax16_1.twinx()
ax16_2.set_ylabel('temp')
ax16_2.plot(b16['FlowTemp_Tenths'].index, b16['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax16_2.legend()

# 17
ax17_1 = axs[3,1]
ax17_1.set_xlabel('time')
ax17_1.set_ylabel('PWM')
ax17_1.plot(b17['HeatDmd'].index, b17['HeatDmd'], '-', color='blue', label='heat')
ax17_1.plot(b17['CoolDmd'].index, b17['CoolDmd'], '-', color='orange', label='cool')
ax17_1.legend()
ax17_2 = ax17_1.twinx()
ax17_2.set_ylabel('temp')
ax17_2.plot(b17['FlowTemp_Tenths'].index, b17['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax17_2.legend()

# 18
ax18_1 = axs[3,2]
ax18_1.set_xlabel('time')
ax18_1.set_ylabel('PWM')
ax18_1.plot(b18['HeatDmd'].index, b18['HeatDmd'], '-', color='blue', label='heat')
ax18_1.plot(b18['CoolDmd'].index, b18['CoolDmd'], '-', color='orange', label='cool')
ax18_1.legend()
ax18_2 = ax18_1.twinx()
ax18_2.set_ylabel('temp')
ax18_2.plot(b18['FlowTemp_Tenths'].index, b18['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax18_2.legend()

# 19
ax19_1 = axs[3,3]
ax19_1.set_xlabel('time')
ax19_1.set_ylabel('PWM')
ax19_1.plot(b19['HeatDmd'].index, b19['HeatDmd'], '-', color='blue', label='heat')
ax19_1.plot(b19['CoolDmd'].index, b19['CoolDmd'], '-', color='orange', label='cool')
ax19_1.legend()
ax19_2 = ax19_1.twinx()
ax19_2.set_ylabel('temp')
ax19_2.plot(b19['FlowTemp_Tenths'].index, b19['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax19_2.legend()

# 20
ax20_1 = axs[3,4]
ax20_1.set_xlabel('time')
ax20_1.set_ylabel('PWM')
ax20_1.plot(b20['HeatDmd'].index, b20['HeatDmd'], '-', color='blue', label='heat')
ax20_1.plot(b20['CoolDmd'].index, b20['CoolDmd'], '-', color='orange', label='cool')
ax20_1.legend()
ax20_2 = ax20_1.twinx()
ax20_2.set_ylabel('temp')
ax20_2.plot(b20['FlowTemp_Tenths'].index, b20['FlowTemp_Tenths'], '-', color='gray', label='temp')
ax20_2.legend()

plt.show()
